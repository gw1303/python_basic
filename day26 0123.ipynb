# %% [markdown]
# # 코랩
# : 주피터를 구글서버에서 동작
# - > 웹브라우져, 공유, 데이터분석 패키지 설치
# - > GPU사용
#
# -> 구글 로그인 -> colab.research.google.com

# %%
# 데이터 시각화
import pandas as pd
import numpy as np

from numpy import NaN,nan,NAN
from pandas import DataFrame

import warnings
warnings.filterwarnings(action='ignore')

import matplotlib.pyplot as plt

# %%
# 한글깨짐 방지 코드
import matplotlib
from matplotlib import font_manager, rc
import platform
if platform.system()=="Windows":
    font_name=font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)
matplotlib.rcParams['axes.unicode_minus']=False

# %%
# matplotlib.org

# %%
x = [1, 2, 3, 4, 5]
y1 = [1, 1, 2, 3, 5]
y2 = [0, 4, 2, 6, 8]
y3 = [1, 3, 5, 7, 9]

y = np.vstack([y1, y2, y3])

labels = ["Fibonacci ", "Evens", "Odds"]

fig, ax = plt.subplots()
ax.stackplot(x, y1, y2, y3, labels=labels)
ax.legend(loc='upper left')
plt.show()

fig, ax = plt.subplots()
ax.stackplot(x, y)
plt.show()

# %%
import matplotlib as mpl
# import matplotlib.pyplot as plt
import matplotlib.pylab as plt

# pylab : 수치해석 s/w -> 시각화 명령 -> 그대로 사용가능

# %%
# %matplotlib inline
# 노트북 내부에 이미지 출력 명령 (메딕 명령)

# %%
# 선 (라인 플롯)
plt.title('plot')
#              x             y   색상,마커모양,선스타일
plt.plot([10,20,30,40], [1,4,9,16], c='b',lw=5, ls='--', marker='X')

# 축 이름
plt.xlabel('x axis')
plt.ylabel('y axis')

plt.show()

# %%
# 틱설정 : 플롯에서 축의 위치 표시 지점
# xticks, yticks

# %%
# np.pi
x = np.linspace(-np.pi,np.pi,256)  # -파이부터 파이까지 256개의 구간으로 쪼갬

c = np.cos(x)

plt.plot(x,c)

plt.xticks([-np.pi,-np.pi/2,0,np.pi/2,np.pi])
plt.yticks([-1,0,1])

plt.show()

# %%
t = np.arange(0,5,0.2)

plt.plot(t,t, 'r--', t,0.5*t**2,'bs-')

# %%
x = np.linspace(-np.pi,np.pi,256)  # -파이부터 파이까지 256개의 구간으로 쪼갬

c, s = np.cos(x), np.sin(x)

plt.plot(x,c, ls='--', label='cosine')
plt.plot(x,s, ls=':', label='cosine')

# 범례
plt.legend(loc=0)  # 0이 최적값에 자동 배정 

plt.show()

# %%
# figure(종이), axes(플롯), axis(축)
# 종이(figure)를 반으로 접어서(axes) 각 axes에 2차원 그림을 출력

# %%
np.random.seed(0)
f1 = plt.figure(figsize=(15,5))
plt.plot(np.random.randn(100),'r*--')
plt.show()

# %%
# subplot(2,1,1)  # 2행 1열 중 1행
# subplot(2,1,2)  # 2행 1열 중 2행
x1 = np.linspace(0.0,5.0)
y1 = np.cos(2*np.pi*x1)*np.exp(-x1)

x2 = np.linspace(0.0,2.0)
y2 = np.cos(2*np.pi*x2)

ax1 = plt.subplot(2,1,1)
plt.plot(x1,y1,'yo-')
plt.title('table1')

ax2 = plt.subplot(2,1,2)
plt.plot(x2,y2,'r.-')
plt.title('table2')

plt.tight_layout(2)

# %%
fig, axes = plt.subplots(2,1)
fig.set_size_inches(10,5)
plt.plot(x1,y1,'yo-',axes=axes[1])

# %%
# barplot
y = [2,3,1]
x = np.arange(len(y))  # [0,1,2]
plt.bar(x,y)

# 각각 바의 이름
plt.xticks(x,['X','Y','Z'])
# 축이름
plt.xlabel('가나다')

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# stemplot
x = np.linspace(0.1, 2*np.pi, 10)
print(x)
plt.stem(x, np.cos(x), '-.')
# Out:
# [0.1        0.78702059 1.47404118 2.16106177 2.84808236 3.53510295
#  4.22212354 4.90914413 5.59616472 6.28318531]
# <StemContainer object of 3 artists>

# %%
# piplot
labels = ['취업','결혼','출산','건강']
sizes = [15,30,45,10]
colors = ['yellow','lightgreen','skyblue','lightcoral']
ex = [0.1,0,0,0]

plt.pie(sizes, labels=labels, colors=colors, shadow=True, startangle=90,explode=ex, autopct='%.1f%%')

plt.show()

# %%
# 히스토그램

x = np.random.randn(100)
#                                구간 수
arr, bins, patchs = plt.hist(x, bins=10, color='lightcoral')
plt.show()
arr  # 각 구간의 건 수
bins # 구간의 범위
# Out:
# <a list of 10 Patch objects>

# %%
# 스캐터플롯 : 두 실수 데이터 집합 사이의 상관관계
x = np.random.normal(0, 1, 500)
y = np.random.normal(0, 1, 500)

plt.scatter(x,y)
plt.show()

# 3차원 데이터 표현
# 점의 크기나 색상을 다르게해서 표현

# %%
help(plt.size)
# Out:
# Help on function size in module numpy:
#
# size(a, axis=None)
#     Return the number of elements along a given axis.
#
#     Parameters
#     ----------
#     a : array_like
#         Input data.
#     axis : int, optional
#         Axis along which the elements are counted.  By default, give
#         the total number of elements.
#
#     Returns
#     -------
#     element_count : int
#         Number of elements along the specified axis.
#
#     See Also
#     --------
#     shape : dimensions of array
#     ndarray.shape : dimensions of array
#     ndarray.size : number of elements in array
#
#     Examples
#     --------
#     >>> a = np.array([[1,2,3],[4,5,6]])
#     >>> np.size(a)
#     6
#     >>> np.size(a,1)
#     3
#     >>> np.size(a,0)
#     2

# %%
# 스캐터플롯에서 3차원 표현해보기
w = np.random.randn(30)
x = np.random.randn(30)
y = np.random.randn(30)
z = np.pi*(10*np.random.rand(30))**2

# c = 컬러, s = 사이즈
plt.scatter(w,x,s=z, c=y)

plt.show()

# %%
from sklearn.datasets import load_digits

# %%
digits = load_digits()
x = digits.images[0]
x
# dir(plt.cm)
plt.imshow(x, cmap=plt.cm.Greens_r)

# %%
import seaborn as sns

# %%
anscombe = sns.load_dataset('anscombe')
# 평균과 분산이 같음 // 통계치가 주는 함정 피해보기
anscombe
# Out:
#    dataset     x      y
# 0        I  10.0   8.04
# 1        I   8.0   6.95
# 2        I  13.0   7.58
# 3        I   9.0   8.81
# 4        I  11.0   8.33
# 5        I  14.0   9.96
# 6        I   6.0   7.24
# 7        I   4.0   4.26
# 8        I  12.0  10.84
# 9        I   7.0   4.82
# 10       I   5.0   5.68
# 11      II  10.0   9.14
# 12      II   8.0   8.14
# 13      II  13.0   8.74
# 14      II   9.0   8.77
# 15      II  11.0   9.26
# 16      II  14.0   8.10
# 17      II   6.0   6.13
# 18      II   4.0   3.10
# 19      II  12.0   9.13
# 20      II   7.0   7.26
# 21      II   5.0   4.74
# 22     III  10.0   7.46
# 23     III   8.0   6.77
# 24     III  13.0  12.74
# 25     III   9.0   7.11
# 26     III  11.0   7.81
# 27     III  14.0   8.84
# 28     III   6.0   6.08
# 29     III   4.0   5.39
# 30     III  12.0   8.15
# 31     III   7.0   6.42
# 32     III   5.0   5.73
# 33      IV   8.0   6.58
# 34      IV   8.0   5.76
# 35      IV   8.0   7.71
# 36      IV   8.0   8.84
# ...

# %%
anscombe['dataset'].unique()  # ['I', 'II', 'III', 'IV']

d1 = anscombe[anscombe['dataset']=='I']
d2 = anscombe[anscombe['dataset']=='II']
d3 = anscombe[anscombe['dataset']=='III']
d4 = anscombe[anscombe['dataset']=='IV']

plt.plot(d1['x'],d1['y'],'r*--')
plt.show()

# %%
plt.plot(d1['x'],d1['y'],'o')

# %%
fig = plt.figure()

# %%
axes1 = fig.add_subplot(2,2,1)  # fig를 2x2로 쪼갰을 때 왼쪽 상단 위치에 더해라
axes2 = fig.add_subplot(2,2,2)
axes3 = fig.add_subplot(2,2,3)
axes4 = fig.add_subplot(2,2,4)

axes1.plot(d1['x'],d1['y'],'ro')
axes2.plot(d2['x'],d2['y'],'go')
axes3.plot(d3['x'],d3['y'],'bo')
axes4.plot(d4['x'],d4['y'],'yo')
# 회귀선은 같으나 데이터의 모습은 너무나 다르다

# 타이틀 부여
axes1.set_title('dataset1')
axes2.set_title('dataset2')
axes3.set_title('dataset3')
axes4.set_title('dataset4')

# 각 axes별 간격 주기
fig.tight_layout()

fig.suptitle('Anscome data',)

fig

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
fig = plt.figure()
axes1 = fig.add_subplot(1,1,1)
# axes1
axes1.hist(tips['total_bill'],bins=6, color='lightcoral')
fig

# %%
scPlot = plt.figure()
axes1=scPlot.add_subplot(1,1,1)
axes1.scatter(tips['total_bill'], tips['tip'])

# %%
boxPlot = plt.figure()
axes1=boxPlot.add_subplot(1,1,1)
axes1.boxplot([tips[tips['sex']=='Female']['tip'],
                tips[tips['sex']=='Male']['tip']],labels=['Female','Male'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x15bff0a4c08>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x15bff0a4d88>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x15bff0a45c8>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x15bff0abd88>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x15bff0abe08>,
# ...
#  'means': []}

# %% [markdown]
# # 데이터의 값에 따라 새로운 값으로 치환

# %%
tips['sex_color'] = tips['sex'].map({'Female':0,'Male':1})
tips

def enc(s):
    if s == 'Female':
        return 0
    else:
        return 1
    
tips['sex_color2'] = tips['sex'].apply(enc)
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size sex_color sex_color2
# 0         16.99  1.01  Female     No   Sun  Dinner     2         0          0
# 1         10.34  1.66    Male     No   Sun  Dinner     3         1          1
# 2         21.01  3.50    Male     No   Sun  Dinner     3         1          1
# 3         23.68  3.31    Male     No   Sun  Dinner     2         1          1
# 4         24.59  3.61  Female     No   Sun  Dinner     4         0          0
# ..          ...   ...     ...    ...   ...     ...   ...       ...        ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3         1          1
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2         0          0
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2         1          1
# 242       17.82  1.75    Male     No   Sat  Dinner     2         1          1
# 243       18.78  3.00  Female     No  Thur  Dinner     2         0          0
#
# [244 rows x 9 columns]

# %%
sPlot = plt.figure()
axes1 = sPlot.add_subplot(1,1,1)
axes1.scatter(x=tips['total_bill'],y=tips['tip'],
             s = tips['size']*10,
             c = tips['sex_color'],
             alpha = 0.4)  # 겹침 파악 가능

# %%
ax = plt.subplots()
# seaborn에서 hist를 그릴 때 사용하는 함수 : distplot
# hist : 정규화해서 넓이가 1인 그래프로 만듦
ax = sns.distplot(tips['total_bill'], kde=True)
#                                   밀집도 그래프

# %%
#                                                양탄자 그래프
ax = sns.distplot(tips['total_bill'], kde=True, rug=True)

# %%
ax = plt.subplots()
sns.countplot(tips['day'])

# %%
df = pd.read_csv('train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
'''타이타닉
스캐터플롯 : 생존/사망여부 , 성별
히스토그램연습(연령을 구간으로 나눠 count)
라인플롯
항구에 따른 생존/사망과 관련된 시각화
'''
# Out:
# '타이타닉\n스캐터플롯 : 생존/사망여부 , 성별\n히스토그램연습(연령을 구간으로 나눠 count)\n라인플롯\n항구에 따른 생존/사망과 관련된 시각화\n'

# %%
# help(plt.figure().add_subplot())

# %%
scPlot = plt.figure()
ax1 = scPlot.add_subplot(1,1,1)
ax1.scatter(df['PassengerId'],df['Age'],c=df['Survived'],alpha=0.9)

# %%
histPlot = plt.figure()
ax1 = histPlot.add_subplot(1,1,1)
bins = [0,8,24,35,60,100]
labels = ['미취학','학생','청년','장년','노년']
ax1.hist(df['Age'], bins=bins, color='lightcoral', histtype='bar')
# Out:
# (array([ 50., 197., 232., 209.,  26.]),
#  array([  0,   8,  24,  35,  60, 100]),
#  <a list of 5 Patch objects>)

# %%
df_sd[0]
# Out:
# Embarked
# C     75
# Q     47
# S    427
# Name: 0, dtype: int64

# %%
df_sd.index
df_sd.columns
# Out:
# Int64Index([0, 1], dtype='int64', name='Survived')

# %%
df_sd = df.pivot_table(index = 'Embarked',values='PassengerId', aggfunc='count', columns='Survived')
df_sd
# Out:
# Survived    0    1
# Embarked
# C          75   93
# Q          47   30
# S         427  217

# %%
fig, ax1 = plt.subplots(nrows = 1)
fig.set_size_inches(15,10)
sns.pointplot(data=df, x = 'Embarked',y='Survived', hue='Survived', ax=ax1)

# %% [markdown]
# 2.
# 1 부터 9까지의 연속된 수를 + 나 - 를 사용하여 합계가 100이 되는 전체 수를 구하시오.
# ex) 1 + 2 + 3 - 4 + 5 + 6 + 78 + 9 = 100
# 12+34-5+67-89=???

# %% [markdown]
# 3.
# 은비는 빵을 좋아한다.
# “아 빵 먹고 싶다.”
# 은비는 자주 가는 빵집에서 두 가지 맛의 빵 밖에 먹지 않는다.
# 하나는 현미 빵으로 하나에 A원에 팔고 있다.
# 또 다른 하나는 단호박 빵으로 하나에 B원에 팔고 있다.
# 은비는 지금 C원을 가지고 있으며, 어떤 빵이든 상관 없이 그냥 많은 개수의 빵을 사고 싶다.
# 두 종류의 개수를 다르게 사도 되고, 한 종류의 빵만 사도 된다.
#  최대 몇 개의 빵을 살 수 있을까?
#
#  [입력]
# 첫 번째 줄에는 세 정수 A, B, C(1 ≤ A, B ≤ 10^3, 1 ≤ C ≤ 10^6)가 공백으로 구분되어 주어진다.
#
# [출력]
# 최대 몇 개의 빵을 살 수 있는지 출력한다.
#
# 입력
# 3 5 6
# 6 8 20
#
# sample_input.txt
# 출력
# 2
# 3

# %%
# 살 수 있는 최대 빵의 수
def bread():
    A, B, C = input('A빵값 B빵값 내돈').split(' ')
    A,B,C = map(int,[A,B,C])
    print(C//min([A,B]),'개')
bread()
# Out:
# A빵값 B빵값 내돈6 8 20
# 3 개

# %%
A,B,C = map(int,[A,B,C])
